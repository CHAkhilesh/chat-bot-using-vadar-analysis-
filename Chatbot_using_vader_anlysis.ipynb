# %%
# !pip install vaderSentiment
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.9 MB/s eta 0:00:00
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score,confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def analyze_sentiment(user_input):
  # Create a VADER sentiment analyzer object
  analyzer = SentimentIntensityAnalyzer()
  # Get sentiment scores
  sentiment_scores = analyzer.polarity_scores(user_input)
  # Determine the sentiment label based on the compound score
  sentiment_score = sentiment_scores['compound']
  if sentiment_score >= 0.05:
    sentiment_label = 'positive'
  elif sentiment_score <= -0.05:
    sentiment_label = 'negative'
  else:
    sentiment_label = 'neutral'
  return sentiment_label, sentiment_score
# Assuming you have a predefined dataset with 'text', 'label', and 'sentiment_score' columns
# Here's the provided example data with 50 rows
data = [

{'text': 'I love this product', 'label': 'positive',
'sentiment_score': 0.9},
{'text': 'This is a great experience', 'label': 'positive',
'sentiment_score': 0.85},
{'text': 'Terrible customer service', 'label': 'negative',
'sentiment_score': 0.1},
{'text': 'The quality is outstanding', 'label': 'positive',
'sentiment_score': 0.88},
{'text': 'I hate waiting so long', 'label': 'negative',
'sentiment_score': 0.12},
{'text': 'This is just okay', 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'Excellent customer support', 'label': 'positive',
'sentiment_score': 0.87},
{'text': 'Worst experience ever', 'label': 'negative',
'sentiment_score': 0.05},
{'text': 'I feel neutral about it', 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'The performance is superb', 'label': 'positive',
'sentiment_score': 0.92},
{'text': "I'm not impressed", 'label': 'negative',
'sentiment_score': 0.15},
{'text': 'This is the best day of my life', 'label':
'positive', 'sentiment_score': 0.95},
{'text': 'I have mixed feelings', 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'I absolutely detest it', 'label': 'negative',
'sentiment_score': 0.08},
{'text': "It's just average", 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'Highly recommend!', 'label': 'positive',
'sentiment_score': 0.93},
{'text': 'Complete waste of time', 'label': 'negative',
'sentiment_score': 0.06},
{'text': 'Not bad at all', 'label': 'neutral',
'sentiment_score': 0.55},
{'text': 'I feel thrilled with it', 'label': 'positive',
'sentiment_score': 0.89},
{'text': 'Absolutely dreadful', 'label': 'negative',
'sentiment_score': 0.03},
{'text': 'I have no strong feelings', 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'Impressive quality', 'label': 'positive',
'sentiment_score': 0.91},
{'text': "I can't complain", 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'I absolutely hate it', 'label': 'negative',
'sentiment_score': 0.08},
{'text': "It's acceptable", 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'Delighted with the results', 'label': 'positive',
'sentiment_score': 0.94},
{'text': 'Absolutely abysmal', 'label': 'negative',
'sentiment_score': 0.02},
{'text': 'I feel neutral about it', 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'Exceptional quality', 'label': 'positive',
'sentiment_score': 0.92},
{'text': "I can't stand it", 'label': 'negative',
'sentiment_score': 0.1},
{'text': 'Not too shabby', 'label': 'neutral',
'sentiment_score': 0.6},
{'text': 'Ecstatic about it', 'label': 'positive',
'sentiment_score': 0.96},
{'text': 'Absolutely terrible', 'label': 'negative',
'sentiment_score': 0.02},
{'text': 'I have no strong feelings', 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'Outstanding performance', 'label': 'positive',
'sentiment_score': 0.91},
{'text': "I can't bear it", 'label': 'negative',
'sentiment_score': 0.1},
{'text': 'Not too bad', 'label': 'neutral',
'sentiment_score': 0.6},
{'text': 'Thrilled with the outcome', 'label': 'positive',
'sentiment_score': 0.88},
{'text': 'Absolutely awful', 'label': 'negative',
'sentiment_score': 0.02},
{'text': 'I have mixed feelings', 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'Superb quality', 'label': 'positive',
'sentiment_score': 0.92},
{'text': 'I can barely tolerate it', 'label': 'negative',
'sentiment_score': 0.12},
{'text': 'Not my cup of tea', 'label': 'neutral',
'sentiment_score': 0.5},
{'text': 'Acceptable performance', 'label': 'positive',
'sentiment_score': 0.78}
]
# Split data into features (X) and labels (y)
X = [item['text'] for item in data]
y_true = [item['label'] for item in data]
# Initialize a list to store sentiment labels and scores
sentiment_labels = []
sentiment_scores = []
# Make predictions using VADER sentiment analysis and collect scores
for text in X:
  sentiment_label, sentiment_score = analyze_sentiment(text)
  sentiment_labels.append(sentiment_label)
  sentiment_scores.append(sentiment_score)
# Calculate performance metrics
accuracy = accuracy_score(y_true, sentiment_labels)
precision = precision_score(y_true, sentiment_labels,
average='weighted')
recall = recall_score(y_true, sentiment_labels,
average='weighted')
f1 = f1_score(y_true, sentiment_labels, average='weighted')
conf_matrix = confusion_matrix(y_true, sentiment_labels)
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-score: {f1:.2f}")
print("Confusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_report(y_true,
sentiment_labels, target_names=['negative', 'neutral','positive']))
# Print the dataset with sentiment labels and scores
# for idx, item in enumerate(data, start=1):
# print(f"{idx}. Text: {item['text']}, Label:
#{item['label']}, Sentiment Score: {item['sentiment_score']:.2f},Sentiment Label: {sentiment_labels[idx-1]}")
actual_scores = [item['sentiment_score'] for item in data]
predicted_scores = [sentiment_scores]
plt.figure(figsize=(8, 6))
sns.kdeplot(actual_scores, color='blue', label='Actual Scores',
shade=True)
sns.kdeplot(predicted_scores, color='green', label='PredictedScores', shade=True)
plt.title('KDE Plot of Actual vs. Predicted Sentiment Scores')
plt.xlabel('Sentiment Scores')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Accuracy: 0.70
# Precision: 0.70
# Recall: 0.70
# F1-score: 0.70
# Confusion Matrix:
#  [[ 9  5  0]
#  [ 2  7  5]
#  [ 0  1 15]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.82      0.64      0.72        14
#      neutral       0.54      0.50      0.52        14
#     positive       0.75      0.94      0.83        16
#
#     accuracy                           0.70        44
#    macro avg       0.70      0.69      0.69        44
# weighted avg       0.70      0.70      0.70        44
# <ipython-input-12-4a6dc67a5190>:141: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(actual_scores, color='blue', label='Actual Scores',
# <ipython-input-12-4a6dc67a5190>:143: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...
